# %%
#Importing the required libraries:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import copy
import os
import ipywidgets as widgets





os.getcwd()
# Out:
# 'C:\\Users\\Monjok J'

# %%
file_path='C:\\Users\\Monjok J\\Downloads\\ENB2012_data.xlsx'
df=pd.read_excel(file_path)
df
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28
# ..    ...    ...    ...     ...  ...  ..  ...  ..    ...    ...
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88  21.40
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54  16.88
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44  17.11
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48  16.61
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64  16.03
#
# [768 rows x 10 columns]

# %%
df.head(50)
# Out:
#       X1     X2     X3      X4   X5  X6   X7  X8      Y1     Y2
# 0   0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.550  21.33
# 1   0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.550  21.33
# 2   0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.550  21.33
# 3   0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.550  21.33
# 4   0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.840  28.28
# 5   0.90  563.5  318.5  122.50  7.0   3  0.0   0  21.460  25.38
# 6   0.90  563.5  318.5  122.50  7.0   4  0.0   0  20.710  25.16
# 7   0.90  563.5  318.5  122.50  7.0   5  0.0   0  19.680  29.60
# 8   0.86  588.0  294.0  147.00  7.0   2  0.0   0  19.500  27.30
# 9   0.86  588.0  294.0  147.00  7.0   3  0.0   0  19.950  21.97
# 10  0.86  588.0  294.0  147.00  7.0   4  0.0   0  19.340  23.49
# 11  0.86  588.0  294.0  147.00  7.0   5  0.0   0  18.310  27.87
# 12  0.82  612.5  318.5  147.00  7.0   2  0.0   0  17.050  23.77
# 13  0.82  612.5  318.5  147.00  7.0   3  0.0   0  17.410  21.46
# ...

# %%
df.tail(50)
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 718  0.62  808.5  367.5  220.50  3.5   4  0.4   4  16.94  16.58
# 719  0.62  808.5  367.5  220.50  3.5   5  0.4   4  16.77  16.79
# 720  0.98  514.5  294.0  110.25  7.0   2  0.4   5  32.84  32.88
# 721  0.98  514.5  294.0  110.25  7.0   3  0.4   5  32.72  33.23
# 722  0.98  514.5  294.0  110.25  7.0   4  0.4   5  32.21  33.76
# 723  0.98  514.5  294.0  110.25  7.0   5  0.4   5  32.73  34.01
# 724  0.90  563.5  318.5  122.50  7.0   2  0.4   5  35.67  33.94
# 725  0.90  563.5  318.5  122.50  7.0   3  0.4   5  35.01  33.14
# 726  0.90  563.5  318.5  122.50  7.0   4  0.4   5  34.72  38.79
# 727  0.90  563.5  318.5  122.50  7.0   5  0.4   5  35.24  37.27
# 728  0.86  588.0  294.0  147.00  7.0   2  0.4   5  32.31  29.69
# 729  0.86  588.0  294.0  147.00  7.0   3  0.4   5  31.81  31.20
# 730  0.86  588.0  294.0  147.00  7.0   4  0.4   5  31.12  36.26
# 731  0.86  588.0  294.0  147.00  7.0   5  0.4   5  32.06  35.71
# ...

# %%
#renaming columns
column_names={'X1':'Relative_Compactness','X2':'Surface_Area',
             'X3':'Wall_Area','X4':'Roof_Area',
             'X5':'Overall_Height','X6':'Orientation','X7':'Glazing_Area','X8':'glazing_Area_Distribution',
             'Y1':'Heating_Load','Y2':'Cooling_Load'}

df=df.rename(columns=column_names)
df
# Out:
#      Relative_Compactness  Surface_Area  Wall_Area  Roof_Area  Overall_Height  \
# 0                    0.98         514.5      294.0     110.25             7.0
# 1                    0.98         514.5      294.0     110.25             7.0
# 2                    0.98         514.5      294.0     110.25             7.0
# 3                    0.98         514.5      294.0     110.25             7.0
# 4                    0.90         563.5      318.5     122.50             7.0
# ..                    ...           ...        ...        ...             ...
# 763                  0.64         784.0      343.0     220.50             3.5
# 764                  0.62         808.5      367.5     220.50             3.5
# 765                  0.62         808.5      367.5     220.50             3.5
# 766                  0.62         808.5      367.5     220.50             3.5
# 767                  0.62         808.5      367.5     220.50             3.5
#
# ...

# %%
df.describe()
# Out:
#        Relative_Compactness  Surface_Area   Wall_Area   Roof_Area  \
# count            768.000000    768.000000  768.000000  768.000000
# mean               0.764167    671.708333  318.500000  176.604167
# std                0.105777     88.086116   43.626481   45.165950
# min                0.620000    514.500000  245.000000  110.250000
# 25%                0.682500    606.375000  294.000000  140.875000
# 50%                0.750000    673.750000  318.500000  183.750000
# 75%                0.830000    741.125000  343.000000  220.500000
# max                0.980000    808.500000  416.500000  220.500000
#
#        Overall_Height  glazing_Area_Distribution  Glazing_Area  \
# count       768.00000                 768.000000    768.000000
# mean          5.25000                   3.500000      0.234375
# std           1.75114                   1.118763      0.133221
# min           3.50000                   2.000000      0.000000
# ...

# %%
df.shape
# Out:
# (768, 10)

# %%
#selecting a sample of the dataset to plot a graph.
#lets say Relative_Compactness vs Cooling_Load


# Select a sample of the dataset
simple_linear_reg_df = df[["Relative_Compactness", "Cooling_load"]].sample(15, random_state=2)

# Regression plot
sns.regplot(x='Relative_Compactness', y='Cooling_load', data=simple_linear_reg_df)

# Show the plot
plt.show()

# %%
df.columns
# Out:
# Index(['Relative_Compactness', 'Surface_Area', 'Wall_Area', 'Roof_Area',
#        'Overall_Height', 'glazing_Area_Distribution', 'Glazing_Area',
#        'glazing_Area_Distribution', 'Heating_Load', 'Cooling_load'],
#       dtype='object')

# %% [markdown]
#  EVALUATION METRICS FOR PERFORMANCE
#
#
# 1).MAE(MEAN ABSOLUTE ERROR)

# %%
import sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
import pandas as pd

# Create a MinMaxScaler
scaler = MinMaxScaler()

# Normalize the dataset
normalized_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# Drop the target columns 'Heating_Load' and 'Cooling_Load' from the features
features_df = normalized_df.drop(columns=['Heating_Load', 'Cooling_load'])
heating_target = normalized_df['Heating_Load']

# Split the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(features_df, heating_target, test_size=0.3, random_state=1)

# Create a Linear Regression model
linear_model = LinearRegression()

# Fit the model to the training dataset
linear_model.fit(x_train, y_train)

# Obtain predictions
predicted_values = linear_model.predict(x_test)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, predicted_values)
round(mae, 3)
# Out:
# 0.063

# %%
from sklearn.metrics import mean_squared_error
rmse=np.sqrt(mean_squared_error(y_test,predicted_values))
round(rmse,3)
# Out:
# 0.088

# %%
from sklearn.metrics import r2_score
r2_score=r2_score(y_test,predicted_values)
round(r2_score,3)
# Out:
# 0.894

# %% [markdown]
# RIDGE REGRESSION:Module 3

# %%
from sklearn.linear_model import Ridge
ridge_reg=Ridge(alpha=0.5)
ridge_reg.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 from sklearn.linear_model import Ridge
#       2 ridge_reg=Ridge(alpha=0.5)
# ----> 3 ridge_reg.fit(x_train,y_train)
#
# NameError: name 'x_train' is not defined

# %% [markdown]
# LASSO REGRESSION

# %%
from sklearn.linear_model import Lasso
lasso_reg=Lasso(alpha=0.001)
lasso_reg.fit(x_train,y_train)


#comparing the effectd of regurlarisation
def get_weights_df(model,feat,col_name):
    #this function returns the weight of every function
    
    weights=pd.Series(model.coef_,feat.columns).sort_values()
    weights_df=pd.DataFrame(weights).reset_index()
    weights_df.columns=['Features',col_name]
    weights_df[col_name].round(3)
    return weighrs_df


linear_model_weights=get_weights_df(linear_model,x_train,'Linear_Model_Weight')
ridge_weights_df=get_weights_df(ridge_reg,x_train,'Ridge_Weight')
lasso_weights_df=get_weights_df(lasso_reg,x_train,'Lasso_Weight')

final_weights=pd.merge(linear_model_weights,ridge_weights_df,on='Features')
final_weights=pd.merge(final_weights,lasso_weights_df,on='Features')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 from sklearn.linear_model import Lasso
#       2 lasso_reg=Lasso(alpha=0.001)
# ----> 3 lasso_reg.fit(x_train,y_train)
#       6 #comparing the effectd of regurlarisation
#       7 def get_weights_df(model,feat,col_name):
#       8     #this function returns the weight of every function
#
# NameError: name 'x_train' is not defined
